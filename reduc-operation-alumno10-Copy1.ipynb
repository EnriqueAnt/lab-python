# %% [markdown]
# ### Reduction operation: the sum of the numbers in the range [0, a)

# %%
import time

def reduc_operation(a):
    """Compute the sum of the numbers in the range [0, a)."""
    x = 0
    for i in range(a):
        x += i
    return x

# Secuencial

value = 1000000

initialTime = time.time()
suma = reduc_operation(value)
finalTime = time.time()

print("Time taken by reduction operation:", (finalTime - initialTime), "seconds")

# Utilizando las operaciones mágicas de ipython
# %timeit -r 2 reduc_operation(value)

print(f"\n \t Computing the sum of numbers in the range [0, value): {suma}\n")
# Out:
# Time taken by reduction operation: 0.31737756729125977 seconds
# 302 ms ± 34.3 ms per loop (mean ± std. dev. of 2 runs, 1 loop each)
#
#  	 Computing the sum of numbers in the range [0, value): 499999500000

# %%
import time

# Crear una lista de Python con 10^6 elementos
my_list = list(range(1000000))

# Opción 1: Sumar con un bucle for
def for_loop_sum():
    total = 0
    for num in my_list:
        total += num
    return total

# Opción 2: Sumar usando sum() de Python
def sum_function():
    return sum(my_list)

# Medición con time.time() para el bucle for
initialTime = time.time()
total_for = for_loop_sum()
finalTime = time.time()
print("Time taken by reduction operation (for loop):", (finalTime - initialTime), "seconds")

# Medición con time.time() para sum()
initialTime = time.time()
total_sum = sum_function()
finalTime = time.time()
print("Time taken by sum() operation:", (finalTime - initialTime), "seconds")

# Utilizando las operaciones mágicas de ipython
print("\nTiming with %timeit:")

# Medición con %timeit para el bucle for
# %timeit -r 2 -n 1000 for_loop_sum()

# Medición con %timeit para la función sum()
# %timeit -r 2 sum_function()

# Mostrar el resultado de las sumas de todas las maneras posibles
print(f"\n\tComputing the sum of numbers in the range [0, 1000000]:")
print(f"\tSum using for loop: {total_for}")
print(f"\tSum using sum(): {total_sum}")
# Out:
# Time taken by reduction operation (for loop): 0.2201085090637207 seconds
# Time taken by sum() operation: 0.03162789344787598 seconds
#
# Timing with %timeit:
# 208 ms ± 978 µs per loop (mean ± std. dev. of 2 runs, 1,000 loops each)
# 30 ms ± 125 µs per loop (mean ± std. dev. of 2 runs, 10 loops each)
#
# 	Computing the sum of numbers in the range [0, 1000000]:
# 	Sum using for loop: 499999500000
# 	Sum using sum(): 499999500000

# %%
import time
import numpy as np

# Convertir la lista a un array de NumPy
my_array = np.array(list(range(1000000)))

# Opción 1: Sumar con un bucle for
def for_loop_sum_array():
    total = 0
    for num in my_array:
        total += num
    return total

# Medición con time.time() para el bucle for
initialTime = time.time()
total_for_array = for_loop_sum_array()
finalTime = time.time()
print("Time taken by reduction operation with array (for loop):", (finalTime - initialTime), "seconds")

# Opción 2: Sumar usando np.sum() de NumPy
def numpy_sum_array():
    return np.sum(my_array)

# Medición con time.time() para np.sum()
initialTime = time.time()
total_numpy_sum_array = numpy_sum_array()
finalTime = time.time()
print("Time taken by np.sum() operation with array:", (finalTime - initialTime), "seconds")

# Utilizando las operaciones mágicas de ipython
print("\nTiming with %timeit:")

# Medición con %timeit para el bucle for
# %timeit -r 2 -n 1000 for_loop_sum_array()

# Medición con %timeit para la función np.sum()
# %timeit -r 2 -n 1000 numpy_sum_array()

# Mostrar el resultado de las sumas de todas las maneras posibles
print(f"\n\tComputing the sum of numbers in the range [0, 1000000]:")
print(f"\tSum using for loop: {total_for_array}")
print(f"\tSum using np.sum(): {total_numpy_sum_array}")
# Out:
# Time taken by reduction operation with array (for loop): 0.6517689228057861 seconds
# Time taken by np.sum() operation with array: 0.0022814273834228516 seconds
#
# Timing with %timeit:
